# %% [markdown]
# ## 简介
#
# 归因分析是对比某个指标在 2 个时段的变化.
#
# 为此, 我们需要准备 2 个数据集, 分别记为 df_a 和 df_b. 每个数据集由维度和指标构成, 假设 df_a 内容如下:
#
# | 操作系统 | 付费状态 | 用户占比 | 转化率 |
# | --- | --- | --- | --- |
# | iOS | 已付费 | 20% | 12% |
# | iOS | 未付费 | 30% | 15% |
# | Android | 已付费 | 10% | 8% |
# | Android | 已付费 | 40% | 17% |
#
# 其中的维度: 操作系统, 付费状态. 指标: 用户占比, 转化率.
#
# 对数据集的指标进行某种计算, 可以得到整体指标. 这个计算可以用简单的 Python 函数表达:
#
# ```python
# def get_metrics(df):
#     return sum(df['用户占比']*df['转化率'])
# ```
#
# 于是, 两个时段的整体指标变化就是 $\Delta = \text{get_metric}(df\_b) - \text{get_metric}(df\_a)$
#
# 我们的分析目标, 就是解释 $\Delta$, 具体来说:
#
# 1. 分析从时段 a 到 b, 每个指标 [用户占比, 转化率] 对 $\Delta$ 分别的贡献.
# 2. 分析同期各个维度下, 每个指标 [用户占比, 转化率] 分别的贡献. 例如: iOS 已付费用户的用户占比变化, 占 $\Delta$ 的比例.
#
# 综上, 归因可将 2 个时段的指标差异, 量化归属到每个维度下的每个指标.
#
# 你可能会问: 为啥不用控制变量法? 具体原因可参见 wiki: Shapley Value.

# %%
# ! pip3 install bytedtqs

# %%
from itertools import combinations
from scipy.special import factorial, comb
import pandas as pd
import numpy as np
import random
from IPython.display import display, HTML

import bytedtqs

# %% [markdown]
# ## 读取 Hive 源数据
#
# - 通过 Python 字符串替换传入 SQL 参数. (如果系统化, 可以做得更友好)
# - 运行 2 段 SQL 得到 2 个时段的指标数据集.

# %% [markdown]
# 注意: 为了分析方便, 我们把 df_a 和 df_b 分别命名成 df_ctl 和 df_trt.

# %%
df_ctl = pd.read_csv('./input_eo_ab_remove_level_test_control_group.csv')
df_trt = pd.read_csv('./input_eo_ab_remove_level_test_treatment_group.csv')

df_ctl = df_ctl[lambda x: x['milestone']!='入群损失']
df_trt = df_trt[lambda x: x['milestone']!='入群损失']

# %% [markdown]
# ## 数据预处理
#
# 如开篇所说, 为了做归因分析, 要定义 `get_metrics` 函数.
#
# 在 Hive 数据集的 columns 中, 选定参与 `get_metrics` 函数运算的指标, 存在 VAR_COLS. 同时给数据集整体指标命名, 存在 METRIC_NAME.
#
# 为避免 df_a 和 df_b 的维度不一致, 还需要进行维度补齐.

# %%
# meta: DIM_COLS, VAR_COLS, METRIC_NAME
# note: DIM_COLS + VAR_COLS = all columns of sql; follow the order in sql
DIM_COLS = ['milestone']
# _dim = ['os','channel','role','mile_stone_name']

VAR_COLS = ['group_users','d8_conversion']
METRIC_NAME = 'd8_conversion'

# operation function: VAR_COLS => METRIC
def get_metrics(df):
    return sum(df['group_users']*df['d8_conversion'])/sum(df['group_users'])

# %%
# fill NA
df_ctl[DIM_COLS] = df_ctl[DIM_COLS].astype(str).fillna('_')
df_trt[DIM_COLS] = df_trt[DIM_COLS].astype(str).fillna('_')
df_ctl[VAR_COLS] = df_ctl[VAR_COLS].fillna(0)
df_trt[VAR_COLS] = df_trt[VAR_COLS].fillna(0)

# select required columns
DIM_COLS, VAR_COLS = sorted(DIM_COLS), sorted(VAR_COLS)
df_ctl = df_ctl[DIM_COLS + VAR_COLS]
df_trt = df_trt[DIM_COLS + VAR_COLS]

# combine dim columns into one for easier analysis
NEW_DIM_COL = '_dim'

df_ctl[NEW_DIM_COL] = df_ctl[DIM_COLS].apply(tuple, axis=1)
df_trt[NEW_DIM_COL] = df_trt[DIM_COLS].apply(tuple, axis=1)

# drop old dim cols
df_ctl, df_trt = df_ctl.drop(DIM_COLS, axis=1), df_trt.drop(DIM_COLS, axis=1)

# find the set of all dim values
DIM_VALS = pd.concat([df_ctl[NEW_DIM_COL], df_trt[NEW_DIM_COL]]).unique()

# make sure both dataframes have records for all dim values
for d in DIM_VALS:
    new_row = dict()
    new_row[NEW_DIM_COL] = d
    for v in VAR_COLS:
        new_row[v] = 0
    # tuple in set
    if d not in set(df_ctl[NEW_DIM_COL].values):
        df_ctl = df_ctl.append(new_row, ignore_index=True)
    if d not in set(df_trt[NEW_DIM_COL].values):
        df_trt = df_trt.append(new_row, ignore_index=True)

# %% [markdown]
# ## 归因分析
#
# 原始的 Shapley Value 有 subset 操作, 理论的复杂度是 $O(2^n)$.
#
# $\varphi _{i}(v)=\sum _{S\subseteq N\setminus \{i\}}{\frac {|S|!\;(n-|S|-1)!}{n!}}(v(S\cup \{i\})-v(S))$
#
# 为了解决这个问题, 利用抽样, 与 "控制变量法" 做了一点权衡. 损失精度, 用 `random.seed()` 保障可复现.

# %%
# set max sample size
SAMPLE_SIZE = 20

# players: dim x variable
players = [(i, j) for i in range(len(DIM_VALS)) for j in range(len(VAR_COLS))]
phi = dict()

# sample
N = len(players)
SAMPLE_SIZE = min(SAMPLE_SIZE, factorial(N))
seq_list = list()

random.seed(666)
for _ in range(SAMPLE_SIZE):
    seq = list(range(N))
    random.shuffle(seq)
    seq_list.append(seq)

# %%
# reuse the same set of sequences for all players
for seq in seq_list:
    # make of copy of ctl
    df_s = df_ctl.copy()
    # current utility
    v_current = get_metrics(df_s)

    for i in range(N):
        # select player p
        p = players[seq[i]]
        # select dim and variable
        d, v = DIM_VALS[p[0]], VAR_COLS[p[1]]
        # update df_s
        df_s.loc[lambda x: x[NEW_DIM_COL]==d, v] = \
            df_trt.loc[lambda x: x[NEW_DIM_COL]==d, v].values
        # calculate marginal utility
        v_si = get_metrics(df_s)
        phi_i = v_si - v_current
        # update current utility
        v_current = v_si
        
        # add utility for player p
        if p in phi:
            phi[p] += phi_i
        else:
            phi[p] = phi_i

# divided by sample size
phi_avg = {k:1.0*v/SAMPLE_SIZE for k, v in phi.items()}

# %% [markdown]
# ## 展示结果
#
# 这部分有些改进空间, 可以更友好, 改进也很简单. 目前是通过看 Top 因素, 定位主要的影响因素.

# %%
# overall metrics
metrics_ctl, metrics_trt = \
get_metrics(df_ctl), get_metrics(df_trt)
delta_metrics = metrics_trt - metrics_ctl

# standardize (because of sampling)
phi_sum = sum(phi.values())
phi_std = {k:1.0*delta_metrics*v/phi_sum for k, v in phi.items()}

# sum of positive and negative contribution
phi_sum_pos, phi_sum_neg = 0, 0

for _, v in phi_std.items():
    if v > 0:
        phi_sum_pos += v
    else:
        phi_sum_neg += v

# save contribution of each player
player_contribution = \
[{'_dim':DIM_VALS[k[0]], 
  '_var':VAR_COLS[k[1]],
  '基期': df_ctl.loc[lambda x: x[NEW_DIM_COL]==DIM_VALS[k[0]], VAR_COLS[k[1]]].values[0],
  '现期': df_trt.loc[lambda x: x[NEW_DIM_COL]==DIM_VALS[k[0]], VAR_COLS[k[1]]].values[0],
  '贡献': v,
  '贡献占整体': v/delta_metrics,
  '贡献占同向': v/phi_sum_pos if v > 0 else v/phi_sum_neg,
 } 
 for k, v in phi_std.items()]

# sort by contribution according to overall change sign
if delta_metrics > 0:
    player_contribution.sort(key=lambda x: -x['贡献'])
else:
    player_contribution.sort(key=lambda x: x['贡献'])

# %%
df_contribution = pd.DataFrame(player_contribution)

df_contribution_split = pd.concat(
    [
        pd.DataFrame(df_contribution.loc[:,NEW_DIM_COL].tolist(), columns=DIM_COLS), 
        df_contribution
    ], 
    axis=1,
)

BASE_VAR_COL = 'group_users'

for c in DIM_COLS:
    for v in VAR_COLS:
        df_contribution_grouped = \
            df_contribution_split[lambda x: x['_var']==v].\
            groupby(c)[['贡献','贡献占整体','贡献占同向']].sum().\
            sort_values(by='贡献占整体', ascending=False)
        
        x = df_contribution_split[lambda x: x['_var']==BASE_VAR_COL]['基期'].sum()
        df_proportion_grouped = df_contribution_split[lambda x: x['_var']==BASE_VAR_COL].\
            groupby(c)['基期'].sum().rename('基期比重') / x
        
        merged = pd.merge(
            df_contribution_grouped, 
            df_proportion_grouped, 
            on=c,
        ).assign(importance=lambda x: np.abs(x['贡献占整体'])/x['基期比重'])
        
        print(f"维度: {c}, 变量: {v}, 累计贡献: {sum(merged['贡献']):.4f}")
        display(
            merged.style.\
                background_gradient(subset=pd.IndexSlice[:,['贡献占整体','基期比重','importance']]).\
                format("{:.4f}")
        )
        print("-"*50)
# Out:
# 维度: milestone, 变量: d8_conversion, 累计贡献: 0.0151
# <style  type="text/css" >
#     #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row0_col4 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row1_col1 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row1_col3 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row1_col4 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row2_col1 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row2_col3 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row2_col4 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row3_col1 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row3_col3 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row3_col4 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row4_col1 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row4_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row4_col4 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row5_col1 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row5_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row5_col4 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row6_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row6_col3 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row6_col4 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row7_col1 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row7_col3 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row8_col1 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row8_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row9_col1 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row9_col3 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row9_col4 {
#             background-color:  #187cb6;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row10_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row10_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row10_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row11_col3 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row11_col4 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }</style><table id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >贡献</th>        <th class="col_heading level0 col1" >贡献占整体</th>        <th class="col_heading level0 col2" >贡献占同向</th>        <th class="col_heading level0 col3" >基期比重</th>        <th class="col_heading level0 col4" >importance</th>    </tr>    <tr>        <th class="index_name level0" >milestone</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68level0_row0" class="row_heading level0 row0" >A1初</th>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row0_col0" class="data row0 col0" >0.0071</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row0_col1" class="data row0 col1" >0.3664</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row0_col2" class="data row0 col2" >0.3339</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row0_col3" class="data row0 col3" >0.4712</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row0_col4" class="data row0 col4" >0.7777</td>
#             </tr>
#             <tr>
#                         <th id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68level0_row1" class="row_heading level0 row1" >A1中</th>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row1_col0" class="data row1 col0" >0.0025</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row1_col1" class="data row1 col1" >0.1288</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row1_col2" class="data row1 col2" >0.1174</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row1_col3" class="data row1 col3" >0.0574</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row1_col4" class="data row1 col4" >2.2442</td>
#             </tr>
#             <tr>
#                         <th id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68level0_row2" class="row_heading level0 row2" >B1初</th>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row2_col0" class="data row2 col0" >0.0025</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row2_col1" class="data row2 col1" >0.1274</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row2_col2" class="data row2 col2" >0.1161</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row2_col3" class="data row2 col3" >0.1420</td>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row2_col4" class="data row2 col4" >0.8969</td>
#             </tr>
#             <tr>
#                         <th id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68level0_row3" class="row_heading level0 row3" >A2中</th>
#                         <td id="T_44fe9a1c_fe3e_11ea_a532_ac1f6b0edb68row3_col0" class="data row3 col0" >0.0018</td>
#                         <td id="T_44f
# --------------------------------------------------
# 维度: milestone, 变量: group_users, 累计贡献: 0.0043
# <style  type="text/css" >
#     #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row0_col4 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row1_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row1_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row1_col4 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row2_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row2_col3 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row2_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row3_col1 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row3_col3 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row3_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row4_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row4_col3 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row4_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row5_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row5_col3 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row5_col4 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row6_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row6_col3 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row6_col4 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row7_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row7_col3 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row7_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row8_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row8_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row8_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row9_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row9_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row9_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row10_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row10_col3 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row10_col4 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row11_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row11_col3 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_45075562_fe3e_11ea_a532_ac1f6b0edb68row11_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }</style><table id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >贡献</th>        <th class="col_heading level0 col1" >贡献占整体</th>        <th class="col_heading level0 col2" >贡献占同向</th>        <th class="col_heading level0 col3" >基期比重</th>        <th class="col_heading level0 col4" >importance</th>    </tr>    <tr>        <th class="index_name level0" >milestone</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68level0_row0" class="row_heading level0 row0" >A1初</th>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row0_col0" class="data row0 col0" >0.0036</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row0_col1" class="data row0 col1" >0.1870</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row0_col2" class="data row0 col2" >0.1704</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row0_col3" class="data row0 col3" >0.4712</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row0_col4" class="data row0 col4" >0.3969</td>
#             </tr>
#             <tr>
#                         <th id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68level0_row1" class="row_heading level0 row1" >A2初</th>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row1_col0" class="data row1 col0" >0.0004</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row1_col1" class="data row1 col1" >0.0214</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row1_col2" class="data row1 col2" >0.0195</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row1_col3" class="data row1 col3" >0.0917</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row1_col4" class="data row1 col4" >0.2337</td>
#             </tr>
#             <tr>
#                         <th id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68level0_row2" class="row_heading level0 row2" >A1中</th>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row2_col0" class="data row2 col0" >0.0002</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row2_col1" class="data row2 col1" >0.0103</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row2_col2" class="data row2 col2" >0.0094</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row2_col3" class="data row2 col3" >0.0574</td>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row2_col4" class="data row2 col4" >0.1796</td>
#             </tr>
#             <tr>
#                         <th id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68level0_row3" class="row_heading level0 row3" >A2中</th>
#                         <td id="T_45075562_fe3e_11ea_a532_ac1f6b0edb68row3_col0" class="data row3 col0" >0.0002</td>
#                         <td id="T_450
# --------------------------------------------------

# %%
# c = ('channel','role')
# for v in VAR_COLS:
#     df_contribution_grouped = \
#         df_contribution_split[lambda x: x['_var']==v].\
#         groupby(c)[['贡献','贡献占整体','贡献占同向']].sum().\
#         sort_values(by='贡献占整体', ascending=False)

#     x = df_contribution_split[lambda x: x['_var']==BASE_VAR_COL]['基期'].sum()
#     df_proportion_grouped = df_contribution_split[lambda x: x['_var']==BASE_VAR_COL].\
#         groupby(c)['基期'].sum().rename('基期比重') / x

#     merged = pd.merge(
#         df_contribution_grouped, 
#         df_proportion_grouped, 
#         on=c,
#     ).assign(comp=lambda x: x['贡献占整体']/x['基期比重'])

#     print(f"dim: {c}, variable: {v}")
#     display(
#         merged.style.\
#             background_gradient(subset=pd.IndexSlice[:,['贡献占整体','comp']]).\
#             format("{:.4f}")
#     )
#     print("-"*50)

# %%
N_REASONS = 50


def decimal_select(num):
    """
    format decimal places for common metrics
    """
    if num >= 100:
        return int(num)
    elif num >= 1:
        return round(num, 2)
    else:
        return round(num, 4)
    

print(f"整体指标 {METRIC_NAME} ({decimal_select(metrics_ctl)} => {decimal_select(metrics_trt)}), \
变化量 = {decimal_select(delta_metrics)}")
print("-"*30)
print("主要影响因素:\n")

for i in range(N_REASONS):
    if i <= len(player_contribution)-1:
        r = player_contribution[i]
        print(f"""{i+1}. {r['_dim']} 的 {r['_var']} ({decimal_select(r['基期'])} => {decimal_select(r['现期'])}).""",
        f"""贡献: {decimal_select(r['贡献'])}.""",
        f"""占{'正' if r['贡献'] > 0 else '负'}向的: {int(r['贡献占同向']*100)}%.""")
# Out:
# 整体指标 d8_conversion (0.0522 => 0.0716), 变化量 = 0.0194
# ------------------------------
# 主要影响因素:
#
# 1. ('A1初',) 的 d8_conversion (0.0345 => 0.0524). 贡献: 0.0071. 占正向的: 33%.
# 2. ('A1初',) 的 group_users (1798 => 1069). 贡献: 0.0036. 占正向的: 17%.
# 3. ('A1中',) 的 d8_conversion (0.0548 => 0.0833). 贡献: 0.0025. 占正向的: 11%.
# 4. ('B1初',) 的 d8_conversion (0.0738 => 0.0906). 贡献: 0.0025. 占正向的: 11%.
# 5. ('A2中',) 的 d8_conversion (0.0622 => 0.0898). 贡献: 0.0018. 占正向的: 8%.
# 6. ('A2初',) 的 d8_conversion (0.0829 => 0.0951). 贡献: 0.0013. 占正向的: 6%.
# 7. ('B2',) 的 d8_conversion (0.043 => 0.0784). 贡献: 0.001. 占正向的: 4%.
# 8. ('A1高',) 的 d8_conversion (0.0506 => 0.0615). 贡献: 0.0005. 占正向的: 2%.
# 9. ('A2初',) 的 group_users (350 => 410). 贡献: 0.0004. 占正向的: 1%.
# 10. ('A1中',) 的 group_users (219 => 396). 贡献: 0.0002. 占正向的: 0%.
# 11. ('A2中',) 的 group_users (193 => 256). 贡献: 0.0002. 占正向的: 0%.
# 12. ('B1初',) 的 group_users (542 => 563). 贡献: 0.0001. 占正向的: 0%.
# 13. ('A2高',) 的 group_users (214 => 225). 贡献: 0.0001. 占正向的: 0%.
# 14. ('C1',) 的 group_users (14 => 9). 贡献: 0.0. 占正向的: 0%.
# 15. ('A2高',) 的 d8_conversion (0.0888 => 0.0889). 贡献: 0.0. 占正向的: 0%.
# 16. ('C2',) 的 d8_conversion (0.0 => 0.0). 贡献: 0.0. 占负向的: 0%.
# 17. ('B2',) 的 group_users (93 => 102). 贡献: -0.0. 占负向的: 0%.
# 18. ('C2',) 的 group_users (1 => 2). 贡献: -0.0. 占负向的: 0%.
# 19. ('B1高',) 的 group_users (17 => 12). 贡献: -0.0001. 占负向的: 4%.
# 20. ('A1高',) 的 group_users (158 => 244). 贡献: -0.0001. 占负向的: 5%.
# 21. ('无等级',) 的 group_users (217 => 232). 贡献: -0.0001. 占负向的: 6%.
# 22. ('C1',) 的 d8_conversion (0.0714 => 0.0). 贡献: -0.0002. 占负向的: 11%.
# 23. ('B1高',) 的 d8_conversion (0.1765 => 0.0833). 贡献: -0.0004. 占负向的: 20%.
# 24. ('无等级',) 的 d8_conversion (0.0415 => 0.0259). 贡献: -0.001. 占负向的: 50%.

# %%
# contribution summary by var
df_res_var = pd.DataFrame(player_contribution).groupby('_var')['贡献'].sum().reset_index()
df_res_var
# Out:
#             _var        贡献
# 0  d8_conversion  0.015122
# 1    group_users  0.004307

# %%
# contribution summary by dim
df_res_dim = pd.merge(
    pd.merge(
    pd.DataFrame(player_contribution).groupby('_dim')['贡献'].sum().sort_values().reset_index(),
        df_ctl,
        on='_dim'
    ),
    df_trt,
    on='_dim'
)

df_res_dim.sort_values(by='贡献', ascending=False)
# Out:
#       _dim        贡献  d8_conversion_x  group_users_x  d8_conversion_y  \
# 11  (A1初,)  0.010753           0.0345           1798           0.0524
# 10  (A1中,)  0.002703           0.0548            219           0.0833
# 9   (B1初,)  0.002590           0.0738            542           0.0906
# 8   (A2中,)  0.001959           0.0622            193           0.0898
# 7   (A2初,)  0.001730           0.0829            350           0.0951
# 6    (B2,)  0.000952           0.0430             93           0.0784
# 5   (A1高,)  0.000410           0.0506            158           0.0615
# 4   (A2高,)  0.000087           0.0888            214           0.0889
# 3    (C2,) -0.000018           0.0000              1           0.0000
# 2    (C1,) -0.000189           0.0714             14           0.0000
# 1   (B1高,) -0.000463           0.1765             17           0.0833
# 0   (无等级,) -0.001085           0.0415            217           0.0259
#
#     group_users_y
# 11           1069
# 10            396
# 9             563
# 8             256
# 7             410
# 6             102
# 5             244
# 4             225
# 3               2
# 2               9
# 1              12
# 0             232
